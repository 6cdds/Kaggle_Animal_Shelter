# %% [markdown]
# # Kaggle Animal Shelter Data Exploration

# %%
# Import modules

import pandas as pd
import numpy as np
import os
import sys
import random
import copy
import cPickle as pickle
import datetime

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import colorlover as cl
import matplotlib.pyplot as plt 

src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

from sklearn.model_selection import ShuffleSplit
from scipy.stats import spearmanr
from scipy import stats
from sklearn import decomposition
from sklearn.preprocessing import StandardScaler
from scipy.stats import boxcox
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

#import plotting_methods as pm

init_notebook_mode(connected=True)

# %reload_ext autoreload
# %autoreload 2

pd.options.display.float_format = '{:,.4f}'.format
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Load data

raw_data_dir = 'C:\Users\Colleen\Documents\Kaggle Animal Shelter\data'

f = open(os.path.join(raw_data_dir, 'train.csv'), 'r')
train_data = pd.read_csv(f)
f.close()

# %% [markdown]
# ## Data Cleaning and Basic Feature Engineering

# %%
train_data.columns
# Out:
# Index([u'AnimalID', u'Name', u'DateTime', u'OutcomeType', u'OutcomeSubtype',
#        u'AnimalType', u'SexuponOutcome', u'AgeuponOutcome', u'Breed',
#        u'Color'],
#       dtype='object')

# %%
'Number of samples: ' + str(train_data.shape[0])
# Out:
# 'Number of samples: 26729'

# %%
train_data.dtypes
# Out:
# AnimalID          object
# Name              object
# DateTime          object
# OutcomeType       object
# OutcomeSubtype    object
# AnimalType        object
# SexuponOutcome    object
# AgeuponOutcome    object
# Breed             object
# Color             object
# dtype: object

# %% [markdown]
# Every feature is likely a string type, but based on the column names we can convert some into other types.
#
# Number of unique values for each feature:

# %%
train_data.apply(lambda x: len(np.unique(x)))
# Out:
# AnimalID          26729
# Name              14065
# DateTime          22918
# OutcomeType           5
# OutcomeSubtype    13628
# AnimalType            2
# SexuponOutcome        6
# AgeuponOutcome       62
# Breed              1380
# Color               366
# dtype: int64

# %% [markdown]
# Now we go through each feature to clean and convert to other types

# %% [markdown]
# ## DateTime
#
# We can convert these into datetime object and look at the distribution.

# %%
train_data['DateTime'].head()
# Out:
# 0    2014-02-12 18:22:00
# 1    2013-10-13 12:44:00
# 2    2015-01-31 12:28:00
# 3    2014-07-11 19:09:00
# 4    2013-11-15 12:52:00
# Name: DateTime, dtype: object

# %%
times = [datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S') for x in train_data['DateTime']]

# %%
iplot([go.Histogram(x = times)])
# Out:
# <div id="70a17286-17d9-4021-8ef3-39e06de30a9b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("70a17286-17d9-4021-8ef3-39e06de30a9b", [{"x": ["2014-02-12 18:22:00", "2013-10-13 12:44:00", "2015-01-31 12:28:00", "2014-07-11 19:09:00", "2013-11-15 12:52:00", "2014-04-25 13:04:00", "2015-03-28 13:11:00", "2015-04-30 17:02:00", "2014-02-04 17:17:00", "2014-05-03 07:48:00", "2013-12-05 15:50:00", "2013-11-04 14:48:00", "2016-02-03 11:27:00", "2015-06-08 16:30:00", "2015-11-25 15:00:00", "2014-07-12 12:10:00", "2014-05-03 16:15:00", "2014-06-07 12:54:00", "2014-05-17 11:32:00", "2014-07-30 17:34:00", "2014-01-19 15:03:00", "2015-09-18 15:19:00", "2015-08-15 14:22:00", "2013-10-28 16:32:00", "2014-04-09 17:44:00", "2015-10-03 15:44:00", "2016-01-15 17:31:00", "2015-03-25 18:50:00", "2015-11-21 13:01:00", "2015-07-30 14:30:00", "2016-01-01 13:57:00", "2015-07-15 15:25:00", "2014-07-03 17:01:00", "2013-11-08 13:24:00", "2015-04-11 16:01:00", "2013-12-06 14:55:00", "2013-10-24 11:22:00", "2014-07-02 13:37:00", "2015-08-11", "2015-07-14 12:16:00", "2015-04-04 17:26:00", "2015-06-23 13:25:00", "2013-12-09 15:04:00", "2014-01-21 15:15:00", "2014-05-28 15:52:00", "2014-08-27 07:50:00", "2014-08-05 11:15:00", "2015-05-05 11:46:00", "2015-03-09 17:57:00", "2013-10-30 15:37:00", "2014-07-28 09:00:00", "2015-10-19 18:58:00", "2014-06-26 17:16:00", "2015-05-14 12:07:00", "2014-11-18 16:05:00", "2015-10-04 15:02:00", "2015-08-16 13:52:00", "2014-07-18 16:23:00", "2014-09-16 14:05:00", "2014-07-07 12:38:00", "2015-08-19 13:32:00", "2014-05-09 18:07:00", "2015-10-06 15:07:00", "2015-09-23 11:45:00", "2014-07-17 17:31:00", "2015-10-27 18:32:00", "2014-12-08 15:53:00", "2015-09-08 15:31:00", "2015-06-16 09:00:00", "2014-05-10 18:18:00", "2014-04-30 17:55:00", "2016-01-29 14:53:00", "2014-03-25 18:15:00", "2015-08-18 11:32:00", "2013-12-28 16:17:00", "2015-08-19 14:28:00", "2014-06-22 17:22:00", "2014-03-21 17:09:00", "2015-06-07 16:07:00", "2015-12-20 19:38:00", "2015-12-17 12:10:00", "2015-09-22 12:10:00", "2015-05-30 18:56:00", "2015-10-12 09:00:00", "2015-02-09 17:17:00", "2014-09-14 18:51:00", "2015-07-18 15:37:00", "2015-07-14 15:04:00", "2014-04-26 18:00:00", "2013-11-18 15:56:00", "2015-12-15 14:16:00", "2016-02-07 14:54:00", "2014-04-10 11:49:00", "2015-02-06 18:56:00", "2014-12-29 15:11:00", "2015-11-15 14:06:00", "2015-12-06 15:12:00", "2014-07-14 19:28:00", "2014-10-24 09:00:00", "2015-01-14 16:18:00", "2014-05-29 17:43:00", "2016-01-28 12:05:00", "2013-10-16 11:50:00", "2015-07-26 14:40:00", "2014-01-30 14:41:00", "2015-04-08 18:06:00", "2015-07-19 18:27:00", "2013-12-20 12:02:00", "2014-03-23 18:43:00", "2014-03-29 11:26:00", "2014-02-11 18:16:00", "2013-12-06 16:53:00", "2013-10-20 16:37:00", "2014-05-06 15:59:00", "2015-07-06 15:48:00", "2015-01-26 16:23:00", "2014-03-22 15:38:00", "2015-11-05", "2015-10-24 18:29:00", "2015-05-03 16:59:00", "2014-04-14 17:00:00", "2014-05-26 11:22:00", "2014-09-21 14:15:00", "2014-11-14 11:57:00", "2014-10-03 18:43:00", "2014-09-11 17:03:00", "2016-01-31 17:22:00", "2014-08-24 09:00:00", "2015-03-22 18:40:00", "2015-01-25 11:15:00", "2015-10-22 17:18:00", "2015-10-26 18:39:00", "2016-01-15 14:03:00", "2015-01-09 15:28:00", "2015-12-15 17:30:00", "2014-06-10 16:41:00", "2015-05-16 15:19:00", "2014-06-18 09:00:00", "2015-10-20 09:00:00", "2014-11-23 18:55:00", "2014-08-05 13:20:00", "2014-02-16 19:38:00", "2016-02-09 16:31:00", "2015-06-28 15:33:00", "2015-11-01 19:11:00", "2015-11-07 19:14:00", "2014-09-26 18:09:00", "2014-10-22 14:37:00", "2014-06-01 17:48:00", "2014-09-12 18:38:00", "2016-02-19 14:58:00", "2015-11-14 13:30:00", "2014-03-03 16:58:00", "2014-02-10 12:34:00", "2014-09-27 12:25:00", "2015-08-15 11:32:00", "2014-07-03 18:45:00", "2014-08-11 15:17:00", "2014-09-15 09:00:00", "2015-12-16 11:28:00", "2015-0 ...

# %% [markdown]
# There doesn't seem to be any outliers or weird values, and the date range agrees with what's given in the competition description.

# %% [markdown]
# ## OutcomeType
#
# This should be the target. We print the unique values to check if they fit the data description.

# %%
np.unique(train_data['OutcomeType'])
# Out:
# array(['Adoption', 'Died', 'Euthanasia', 'Return_to_owner', 'Transfer'], dtype=object)

# %%
train_data['OutcomeType'].groupby(train_data['OutcomeType']).count().append(pd.Series({'nan': len(train_data['OutcomeType']) - train_data['OutcomeType'].count()}))
# Out:
# Adoption           10769
# Died                 197
# Euthanasia          1555
# Return_to_owner     4786
# Transfer            9422
# nan                    0
# dtype: int64

# %% [markdown]
# ## OutcomeSubtype
#
# Printing the unique values shows there are missing values here.

# %% [markdown]
# Re-printing them, remove missing values gives a much more mangeable number.  This variable is clearly categorical.  We may be able to merge some of these categories, but we need to be careful to not remove any information. We'll leave it for now.

# %%
train_data['OutcomeSubtype'].groupby(train_data['OutcomeSubtype']).count().append(pd.Series({'nan': len(train_data['OutcomeSubtype']) - train_data['OutcomeSubtype'].count()}))
# Out:
# Aggressive               320
# At Vet                     4
# Barn                       2
# Behavior                  86
# Court/Investigation        6
# Enroute                    8
# Foster                  1800
# In Foster                 52
# In Kennel                114
# In Surgery                 3
# Medical                   66
# Offsite                  165
# Partner                 7816
# Rabies Risk               74
# SCRP                    1599
# Suffering               1002
# nan                    13612
# dtype: int64

# %%
def plot_cnts(feats1, levels1 = None, feats2, levels2 = None):
    
    if levels1 == None:
        f1 = feats1
    else:
        f1 = feats1.loc[np.array([x in levels1 for x in feats1])]
    cnts1 = f1.groupby(f1).count()
        
    if levels2 == None:
        f2 = feats2
    else:
        f2 = feats2.loc[np.array([x in levels2 for x in feats2])]     
    cnts2 = f2.groupby(f2).count()
    
    return [go.Bar(x = cnts1)]

# %% [markdown]
# ## AnimalType
#
# This one is categorical and simple - cat or dog

# %%
np.unique(train_data['AnimalType'])
# Out:
# array(['Cat', 'Dog'], dtype=object)

# %%
train_data['AnimalType'].groupby(train_data['AnimalType']).count().append(pd.Series({'nan': len(train_data['AnimalType']) - train_data['AnimalType'].count()}))
# Out:
# Cat    11134
# Dog    15595
# nan        0
# dtype: int64

# %%
pd.crosstab(index=train_data['AnimalType'], columns=train_data['OutcomeType'])
# Out:
# OutcomeType  Adoption  Died  Euthanasia  Return_to_owner  Transfer
# AnimalType
# Cat              4272   147         710              500      5505
# Dog              6497    50         845             4286      3917

# %% [markdown]
# ## SexuponOutcome
#
# This one is also categorical, indicating spayed/neutered status.  The missing value and 'Unknown' could likely be merged.

# %%
np.unique(train_data['SexuponOutcome'])
# Out:
# array([nan, 'Intact Female', 'Intact Male', 'Neutered Male',
#        'Spayed Female', 'Unknown'], dtype=object)

# %%
train_data['SexuponOutcome'].groupby(train_data['SexuponOutcome']).count().append(pd.Series({'nan': len(train_data['SexuponOutcome']) - train_data['SexuponOutcome'].count()}))
# Out:
# Intact Female    3511
# Intact Male      3525
# Neutered Male    9779
# Spayed Female    8820
# Unknown          1093
# nan                 1
# dtype: int64

# %% [markdown]
# ## AgeuponOutcome
#
# This variable can be converted to nominal, using the number of days as the measure of age

# %%
np.unique(train_data['AgeuponOutcome'])
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, '0 years', '1 day', '1 month', '1 week',
#        '1 weeks', '1 year', '10 months', '10 years', '11 months',
#        '11 years', '12 years', '13 years', '14 years', '15 years',
#        '16 years', '17 years', '18 years', '19 years', '2 days',
#        '2 months', '2 weeks', '2 years', '20 years', '3 days', '3 months',
#        '3 weeks', '3 years', '4 days', '4 months', '4 weeks', '4 years',
#        '5 days', '5 months', '5 weeks', '5 years', '6 days', '6 months',
#        '6 years', '7 months', '7 years', '8 months', '8 years', '9 months',
#        '9 years'], dtype=object)

# %%
def get_age(s):
    
    if (s == 'nan') or (isinstance(s, float) and np.isnan(s)):
        return s
    
    n = s.split(' ')
    num = int(n[0])
    time = n[1]
    if num == 0:
        return 0
    elif 'year' in time:
        return num * 365
    elif 'month' in time:
        return num * 30
    else:
        return num

# %%
ages = [get_age(s) for s in train_data['AgeuponOutcome']]

# %%
iplot([go.Histogram(x = ages)])
# Out:
# <div id="cc9d6e9c-584c-433e-ab5d-3084a9c95b07" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cc9d6e9c-584c-433e-ab5d-3084a9c95b07", [{"x": [365, 365, 730, 3, 730, 30, 3, 3, 150, 365, 730, 730, 1460, 730, 365, 90, 3, 2, 730, 365, 60, 365, 730, 300, 60, 30, 180, 1825, 60, 2555, 1095, 120, 60, 1825, 1095, 1095, 1095, 60, 120, 3, 2555, 60, 60, 1460, 730, 4380, 3285, 3, 150, 2190, 365, 90, 3, 730, 60, 1, 60, 365, 1460, 730, 365, 4015, 30, 730, 2, 2190, 180, 60, 60, 365, 60, 730, 1095, 365, 1460, 730, 90, 365, 60, 730, 365, 2, 4, 730, 4380, 365, 60, 2, 90, 90, 150, 1095, 2555, 730, 120, 3285, 210, 60, 1095, 1095, 1825, 1825, 2, 2, 1460, 1460, 60, 730, 730, 3285, 1825, 365, 730, 3, 150, 2190, 365, 90, 30, 1095, 1825, 2920, 60, 2555, 60, 1825, 365, 90, 730, 3285, 1095, 1095, 365, 730, 365, 730, 730, 730, 90, 30, 60, 300, 730, 60, 180, 60, 365, 180, 365, 3, 730, 330, 90, 730, 730, 730, 120, 120, 150, 60, 2555, 1460, 3, 180, 150, 2920, 60, 30, 150, 30, 120, 365, 730, 4015, 60, 60, 60, 30, 2555, 4, 1460, 730, 365, 730, 4, 365, 730, 300, 1460, 120, 2190, 270, 1095, 240, 300, 365, 365, 365, 90, 2190, 365, 730, 1825, 4380, 730, 2190, 90, 240, 365, 5475, 3, 150, 730, 730, 730, 730, 3, 365, 730, 4, 1460, 3, 60, 365, 60, 365, 1095, 3285, 730, 1825, 730, 730, 2555, 365, 2190, 60, 365, 60, 2190, 60, 730, 2555, 90, 1095, 730, 2555, 30, 730, 150, 1460, 730, 2555, 365, 30, 30, 60, 1095, 1460, 365, 730, 3650, 60, 3650, 730, 2555, 365, 1825, 2190, 1, 2555, 365, 365, 2, 365, 1825, 730, 300, 90, 270, 30, 0, 1825, 240, 365, 60, 90, 5110, 2555, 730, 180, 330, 1095, 60, 365, 4, 1460, 2920, 90, 60, 120, 730, 2190, 330, 365, 1460, 60, 730, 60, 180, 2920, 1095, 730, 60, 3, 60, 1460, 1825, 730, 180, 730, 3650, 180, 60, 180, 2920, 180, 90, 365, 365, 60, 2, 730, 60, 270, 1460, 120, 3, 2190, 60, 240, 30, 120, 60, 730, 120, 365, 90, 60, 120, 1825, 730, 2, 60, 300, 730, 300, 4, 365, 210, 730, 2555, 60, 4380, 1095, 90, 730, 4380, 365, 1095, 30, 6, 270, 60, 730, 2555, 120, 3650, 1825, 730, 1825, 150, 365, 365, 120, 730, 1095, 4, 3, 3, 730, 365, 2, 730, 270, 1095, 30, 730, 730, 120, 1095, 365, 30, 365, 60, 3285, 730, 180, 90, 30, 365, 730, 1095, 60, 730, 730, 60, 4380, 730, 240, 3650, 60, 90, 365, 730, 60, 90, 2555, 730, 120, 60, 90, 730, 180, 4, 90, 150, 60, 30, 365, 30, 1095, 1095, 2190, 240, 120, 1095, 4, 60, 60, 365, 1825, 2555, 60, 1095, 30, 2190, 60, 730, 2, 365, 730, 60, 60, 2920, 1, 4380, 365, 4015, 2, 730, 730, 730, 1095, 5, 3, 300, 2555, 2555, 1095, 730, 730, 365, 150, 240, 90, 365, 120, 365, 365, 60, 240, 365, 1825, 4, 1095, 1095, 60, 90, 3650, 1825, 4, 2555, 365, 90, 1460, 1095, 30, 2, 2, 6, 365, 4, 2920, 30, 3650, 120, 1095, 730, 2920, 1095, 270, 90, 3285, 365, 120, 1460, 730, 2, 60, 3650, 60, 1095, 2190, 2555, 60, 120, 1825, 2190, 2920, 730, 60, 120, 365, 60, 1825, 60, 1095, 1095, 1095, 30, 60, 730, 1460, 3, 2555, 60, 1460, 60, 730, 30, 1095, 90, 4, 30, 150, 60, 30, 730, 4380, 730, 270, 3285, 730, 60, 150, 120, 2, 60, 2, 60, 60, 3, 120, 730, 4380, 730, 730, 1095, 60, 1095, 1825, 240, 3650, 30, 365, 2190, 1095, 60, 180, 365, 2, 730, 3, 150, 365, 365, 365, 60, 60, 3650, 730, 90, 2, 2, 365, 2555, 60, 730, 4380, 4, 60, 365, 60, 30, 60, 30, 365, 365, 365, 30, 30, 60, 365, 730, 60, 730, 120, 365, 730, 210, 365, 1095, 180, 1095, 365, 730, 300, 60, 1825, 60, 3650, 730, 120, 365, 365, 180, 1095, 60, 365, 60, 120, 365, 365, 730, 180, 30, 30, 120, 60, 240, 4380, 4380, 3, 365, 30, 1825, 2920, 2920, 365, 730, 365, 60, 30, 730, 60, 1460, 60, 60, 1825, 150, 60, 60, 1095, 1095, 30, 365, 730, 60, 730, 2190, 150, 1825, 60, 90, 60, 5475, 2920, 365, 90, 365, 730, 30, 60, 3, 90, 3285, 2555, 2190, 3650, 60, 2920, 270, 1095, 240, 3, 270, 2, 300, 4015, 365, 1825, 730, 1825, 365, 1095, 365, 30, 730, 6, 365, 4380, 5, 730, 365, 365, 730, 365, 180, 60, 90, 730, 150, 730, 365, 730, 365, 60, 730 ...

# %% [markdown]
# There are a range of ages but its quite skewed.

# %% [markdown]
# ## Breed
#
# There are a lot of categories here. We definitely need to compress these or come up with other features based on it.

# %%
x = 'Breed'
cnts = train_data[x].groupby(train_data[x]).count().append(pd.Series({'nan': len(train_data[x]) - train_data[x].count()}))

# %%
len(cnts)
# Out:
# 1381

# %%
cnts.sort_values()
# Out:
# nan                                                   0
# Newfoundland/Queensland Heeler                        1
# Newfoundland/Great Pyrenees                           1
# Newfoundland/Border Collie                            1
# Newfoundland/Australian Cattle Dog                    1
# Chinese Crested/Chihuahua Longhair                    1
# Chinese Crested/Papillon                              1
# Munchkin Longhair Mix                                 1
# Miniature Schnauzer/Whippet                           1
# Chihuahua Shorthair/Smooth Fox Terrier                1
# Chinese Sharpei/Airedale Terrier                      1
# Chinese Sharpei/Basset Hound                          1
# Miniature Schnauzer/West Highland                     1
# Chinese Sharpei/Great Dane                            1
# Miniature Schnauzer/Soft Coated Wheaten Terrier       1
# Chinese Sharpei/Pit Bull                              1
# Miniature Schnauzer/Shih Tzu                          1
# Miniature Schnauzer/Scottish Terrier                  1
# Miniature Schnauzer/Queensland Heeler                 1
# Chinese Sharpei/Australian Cattle Dog                 1
# Chihuahua Shorthair/Shih Tzu                          1
# Chihuahua Shorthair/Shetland Sheepdog                 1
# Chihuahua Shorthair/Schipperke                        1
# Nova Scotia Duck Tolling Retriever                    1
# Norwich Terrier/Pug                                   1
# Chihuahua Shorthair/Finnish Spitz                     1
# Chihuahua Shorthair/French Bulldog                    1
# Norwich Terrier/Cairn Terrier                         1
# Norwich Terrier/Border Terrier                        1
# Norwegian Forest Cat Mix                              1
#                                                    ...
# Staffordshire Mix                                    94
# Australian Kelpie Mix                                95
# Chihuahua Shorthair/Dachshund                        98
# Shih Tzu Mix                                        100
# Cairn Terrier Mix                                   102
# American Bulldog Mix                                109
# Rottweiler Mix                                      113
# Beagle Mix                                          124
# Miniature Schnauzer Mix                             136
# Siberian Husky Mix                                  138
# Chihuahua Longhair Mix                              142
# Yorkshire Terrier Mix                               143
# Domestic Shorthair                                  143
# Jack Russell Terrier Mix                            146
# Catahoula Mix                                       157
# Rat Terrier Mix                                     157
# Australian Shepherd Mix                             163
# Border Collie Mix                                   229
# Miniature Poodle Mix                                233
# Boxer Mix                                           245
# Dachshund Mix                                       318
# Australian Cattle Dog Mix                           367
# Siamese Mix                                         389
# Domestic Longhair Mix                               520
# German Shepherd Mix                                 575
# Domestic Medium Hair Mix                            839
# Labrador Retriever Mix                             1363
# Chihuahua Shorthair Mix                            1766
# Pit Bull Mix                                       1906
# Domestic Shorthair Mix                             8810
# Length: 1381, dtype: int64

# %%
from itertools import chain
breeds = np.unique(list(chain.from_iterable([x.split('/') for x in train_data['Breed']])))
breed_cnts = dict([(x, sum([x in y for y in train_data['Breed']])) for x in breeds])

# %%
len(breed_cnts)
# Out:
# 397

# %%
breed_cnts
# Out:
# {'Abyssinian Mix': 2,
#  'Affenpinscher': 10,
#  'Affenpinscher Mix': 6,
#  'Afghan Hound Mix': 1,
#  'Airedale Terrier': 9,
#  'Airedale Terrier Mix': 5,
#  'Akita': 29,
#  'Akita Mix': 11,
#  'Alaskan Husky': 26,
#  'Alaskan Husky Mix': 10,
#  'Alaskan Malamute': 17,
#  'Alaskan Malamute Mix': 5,
#  'American Bulldog': 147,
#  'American Bulldog Mix': 109,
#  'American Eskimo': 14,
#  'American Eskimo Mix': 9,
#  'American Foxhound': 7,
#  'American Foxhound Mix': 2,
#  'American Pit Bull Terrier': 90,
#  'American Pit Bull Terrier Mix': 68,
#  'American Shorthair Mix': 9,
#  'American Staffordshire Terrier': 121,
#  'American Staffordshire Terrier Mix': 92,
#  'Anatol Shepherd': 152,
#  'Anatol Shepherd Mix': 76,
#  'Angora Mix': 7,
#  'Australian Cattle Dog': 640,
#  'Australian Cattle Dog Mix': 367,
#  'Australian Kelpie': 133,
#  'Australian Kelpie Mix': 95,
#  'Australian Shepherd': 272,
#  'Australian Shepherd Mix': 163,
#  'Australian Terrier Mix': 4,
#  'Balinese Mix': 5,
#  'Basenji': 24,
#  'Basenji Mix': 11,
#  'Basset Hound': 101,
#  'Basset Hound Mix': 43,
#  'Beagle': 311,
#  'Beagle Mix': 124,
#  'Bearded Collie Mix': 2,
#  'Beauceron': 14,
#  'Beauceron Mix': 11,
#  'Bedlington Terr Mix': 3,
#  'Belgian Malinois': 20,
#  'Belgian Malinois Mix': 15,
#  'Belgian Sheepdog': 3,
#  'Belgian Sheepdog Mix': 2,
#  'Belgian Tervuren': 2,
#  'Belgian Tervuren Mix': 1,
#  'Bengal': 5,
#  'Bengal Mix': 3,
#  'Bernese Mountain Dog': 9,
#  'Bernese Mountain Dog Mix': 6,
#  'Bichon Frise': 22,
#  'Bichon Frise Mix': 14,
#  'Black': 130,
#  'Black Mouth Cur': 101,
#  'Black Mouth Cur Mix': 63,
#  'Bloodhound': 12,
#  'Bloodhound Mix': 7,
#  'Blue Lacy': 74,
#  'Blue Lacy Mix': 39,
#  'Bluetick Hound': 7,
#  'Bluetick Hound Mix': 5,
#  'Boerboel': 4,
#  'Boerboel Mix': 3,
#  'Bombay Mix': 5,
#  'Border Collie': 432,
#  'Border Collie Mix': 229,
#  'Border Terrier': 74,
#  'Border Terrier Mix': 30,
#  'Borzoi': 1,
#  'Boston Terrier': 86,
#  'Boston Terrier Mix': 42,
#  'Boxer': 437,
#  'Boxer Mix': 245,
#  'Boykin Span': 4,
#  'Boykin Span Mix': 3,
#  'British Shorthair': 5,
#  'British Shorthair Mix': 3,
#  'Brittany': 15,
#  'Brittany Mix': 6,
#  'Bruss Griffon': 28,
#  'Bruss Griffon Mix': 20,
#  'Bull Terrier': 140,
#  'Bull Terrier Miniature': 3,
#  'Bull Terrier Miniature Mix': 2,
#  'Bull Terrier Mix': 95,
#  'Bulldog': 230,
#  'Bulldog Mix': 153,
#  'Bullmastiff': 11,
#  'Bullmastiff Mix': 8,
#  'Burmese': 1,
#  'Cairn Terrier': 176,
#  'Cairn Terrier Mix': 102,
#  'Canaan Dog': 6,
#  'Canaan Dog Mix': 3,
#  'Cane Corso': 8,
#  'Cane Corso Mix': 4,
#  'Cardigan Welsh Corgi': 127,
#  'Cardigan Welsh Corgi Mix': 54,
#  'Carolina Dog': 49,
#  'Carolina Dog Mix': 39,
#  'Catahoula': 272,
#  'Catahoula Mix': 157,
#  'Cavalier Span': 19,
#  'Cavalier Span Mix': 8,
#  'Chesa Bay Retr': 14,
#  'Chesa Bay Retr Mix': 12,
#  'Chihuahua Longhair': 193,
#  'Chihuahua Longhair Mix': 142,
#  'Chihuahua Shorthair': 2398,
#  'Chihuahua Shorthair Mix': 1766,
#  'Chinese Crested': 5,
#  'Chinese Crested Mix': 3,
#  'Chinese Sharpei': 94,
#  'Chinese Sharpei Mix': 25,
#  'Chow Chow': 150,
#  'Chow Chow Mix': 57,
#  'Cocker Spaniel': 107,
#  'Cocker Spaniel Mix': 45,
#  'Collie Rough': 28,
#  'Collie Rough Mix': 9,
#  'Collie Smooth': 50,
#  'Collie Smooth Mix': 29,
#  'Cornish Rex Mix': 1,
#  'Cymric Mix': 2,
#  'Dachshund': 787,
#  'Dachshund Longhair': 55,
#  'Dachshund Longhair Mix': 32,
#  'Dachshund Mix': 318,
#  'Dachshund Wirehair': 64,
#  'Dachshund Wirehair Mix': 23,
#  'Dalmatian': 23,
#  'Dalmatian Mix': 10,
#  'Devon Rex': 2,
#  'Devon Rex Mix': 1,
#  'Doberman Pinsch': 79,
#  'Doberman Pinsch Mix': 45,
#  'Dogo Argentino': 17,
#  'Dogo Argentino Mix': 13,
#  'Dogue De Bordeaux': 6,
#  'Dogue De Bordeaux Mix': 4,
#  'Domestic Longhair': 548,
#  'Domestic Longhair Mix': 520,
#  'Domestic Medium Hair': 884,
#  'Domestic Medium Hair Mix': 839,
#  'Domestic Shorthair': 8971,
#  'Domestic Shorthair Mix': 8810,
#  'Dutch Shepherd': 9,
#  'Dutch Shepherd Mix': 7,
#  'English Bulldog': 53,
#  'English Bulldog Mix': 27,
#  'English Cocker Spaniel': 4,
#  'English Cocker Spaniel Mix': 1,
#  'English Coonhound': 8,
#  'English Coonhound Mix': 5,
#  'English Foxhound': 4,
#  'English Foxhound Mix': 1,
#  'English Pointer': 18,
#  'English Pointer Mix': 14,
#  'English Setter': 5,
#  'English Setter Mix': 2,
#  'English Shepherd': 3,
#  'English Shepherd Mix': 2,
#  'English Springer Spaniel': 9,
#  'English Springer Spaniel Mix': 4,
#  'Entlebucher Mix': 1,
#  'Exotic Shorthair Mix': 2,
#  'Feist Mix': 6,
#  'Field Spaniel Mix': 2,
#  'Finnish Spitz': 14,
#  'Finnish Spitz Mix': 7,
#  'Flat Coat Retriever': 54,
#  'Flat Coat Retriever Mix': 37,
#  'French Bulldog': 14,
#  'French Bulldog Mix': 6,
#  'German Pinscher': 3,
#  'German Pinscher Mix': 1,
#  'German Shepherd': 962,
#  'German Shepherd Mix': 575,
#  'German Shorthair Pointer': 25,
#  'German Shorthair Pointer Mix': 19,
#  'German Wirehaired Pointer': 5,
#  'German Wirehaired Pointer Mix': 3,
#  'Glen Of Imaal': 4,
#  'Glen Of Imaal Mix': 3,
#  'Golden Retriever': 126,
#  'Golden Retriever Mix': 66,
#  'Great Dane': 59,
#  'Great Dane Mix': 21,
#  'Great Pyrenees': 172,
#  'Great Pyrenees Mix': 86,
#  'Greater Swiss Mountain Dog Mix': 4,
#  'Greyhound': 50,
#  'Greyhound Mix': 20,
#  'Harrier': 27,
#  'Harrier Mix': 15,
#  'Havana Brown Mix': 1,
#  'Havanese': 17,
#  'Havanese Mix': 10,
#  'Himalayan': 18,
#  'Himalayan Mix': 15,
#  'Hovawart Mix': 1,
#  'Ibizan Hound': 4,
#  'Ibizan Hound Mix': 2,
#  'Irish Setter': 3,
#  'Irish Terrier': 6,
#  'Irish Terrier Mix': 5,
#  'Irish Wolfhound': 6,
#  'Irish Wolfhound Mix': 3,
#  'Italian Greyhound': 26,
#  'Italian Greyhound Mix': 12,
#  'Jack Russell Terrier': 270,
#  'Jack Russell Terrier Mix': 146,
#  'Japanese Bobtail': 8,
#  'Japanese Bobtail Mix': 6,
#  'Japanese Chin': 3,
#  'Japanese Chin Mix': 2,
#  'Javanese Mix': 2,
#  'Jindo Mix': 3,
#  'Keeshond': 7,
#  'Keeshond Mix': 5,
#  'Kuvasz': 1,
#  'Labrador Retriever': 2274,
#  'Labrador Retriever Mix': 1363,
#  'Landseer Mix': 6,
#  'Leonberger': 9,
#  'Leonberger Mix': 8,
#  'Lhasa Apso': 77,
#  'Lhasa Apso Mix': 41,
#  'Lowchen Mix': 1,
#  'Maine Coon': 47,
#  'Maine Coon Mix': 44,
#  'Maltese': 131,
#  'Maltese Mix': 49,
#  'Manchester Terrier': 68,
#  'Manchester Terrier Mix': 40,
#  'Manx': 49,
#  'Manx Mix': 44,
#  'Mastiff': 58,
#  'Mastiff Mix': 26,
#  'Mexican Hairless Mix': 1,
#  'Miniature Pinscher': 115,
#  'Miniature Pinscher Mix': 69,
#  'Miniature Poodle': 431,
#  'Miniature Poodle Mix': 233,
#  'Miniature Schnauzer': 266,
#  'Miniature Schnauzer Mix': 136,
#  'Munchkin Longhair Mix': 1,
#  'Neapolitan Mastiff': 3,
#  'Neapolitan Mastiff Mix': 2,
#  'Newfoundland': 14,
#  'Newfoundland Mix': 6,
#  'Norfolk Terrier': 34,
#  'Norfolk Terrier Mix': 21,
#  'Norwegian Elkhound Mix': 1,
#  'Norwegian Forest Cat Mix': 1,
#  'Norwich Terrier': 18,
#  'Norwich Terrier Mix': 15,
#  'Nova Scotia Duck Tolling Retriever': 5,
#  'Nova Scotia Duck Tolling Retriever Mix': 1,
#  'Ocicat Mix': 1,
#  'Old English Bulldog Mix': 3,
#  'Old English Sheepdog': 2,
#  'Otterhound Mix': 1,
#  'Papillon': 29,
#  'Papillon Mix': 13,
#  'Parson Russell Terrier': 30,
#  'Parson Russell Terrier Mix': 18,
#  'Patterdale Terr': 6,
#  'Patterdale Terr Mix': 5,
#  'Pbgv': 15,
#  'Pbgv Mix': 7,
#  'Pekingese': 43,
#  'Pekingese Mix': 26,
#  'Pembroke Welsh Corgi': 42,
#  'Pembroke Welsh Corgi Mix': 18,
#  'Persian': 16,
#  'Persian Mix': 12,
#  'Pharaoh Hound': 13,
#  'Pharaoh Hound Mix': 9,
#  'Picardy Sheepdog Mix': 3,
#  'Pit Bull': 2392,
#  'Pit Bull Mix': 1906,
#  'Pixiebob Shorthair Mix': 3,
#  'Plott Hound': 124,
#  'Plott Hound Mix': 73,
#  'Podengo Pequeno Mix': 5,
#  'Pointer': 239,
#  'Pointer Mix': 129,
#  'Pomeranian': 73,
#  'Pomeranian Mix': 39,
#  'Port Water Dog Mix': 2,
#  'Presa Canario': 3,
#  'Presa Canario Mix': 2,
#  'Pug': 143,
#  'Pug Mix': 49,
#  'Queensland Heeler': 73,
#  'Queensland Heeler Mix': 51,
#  'Ragdoll': 13,
#  'Ragdoll Mix': 11,
#  'Rat Terrier': 257,
#  'Rat Terrier Mix': 157,
#  'Redbone Hound': 34,
#  'Redbone Hound Mix': 21,
#  'Rex': 4,
#  'Rhod Ridgeback': 53,
#  'Rhod Ridgeback Mix': 25,
#  'Rottweiler': 209,
#  'Rottweiler Mix': 113,
#  'Russian Blue': 36,
#  'Russian Blue Mix': 33,
#  'Saluki': 5,
#  'Saluki Mix': 3,
#  'Samoyed Mix': 3,
#  'Schipperke': 12,
#  'Schipperke Mix': 7,
#  'Schnauzer Giant': 5,
#  'Schnauzer Giant Mix': 4,
#  'Scottish Terrier': 7,
#  'Scottish Terrier Mix': 2,
#  'Sealyham Terr Mix': 1,
#  'Shetland Sheepdog': 42,
#  'Shetland Sheepdog Mix': 22,
#  'Shiba Inu': 22,
#  'Shiba Inu Mix': 17,
#  'Shih Tzu': 190,
#  'Shih Tzu Mix': 100,
#  'Siamese': 430,
#  'Siamese Mix': 389,
#  'Siberian Husky': 221,
#  'Siberian Husky Mix': 138,
#  'Silky Terrier': 8,
#  'Silky Terrier Mix': 7,
#  'Skye Terrier': 5,
#  'Skye Terrier Mix': 3,
#  'Smooth Fox Terrier': 11,
#  'Smooth Fox Terrier Mix': 10,
#  'Snowshoe': 78,
#  'Snowshoe Mix': 75,
#  'Soft Coated Wheaten Terrier': 31,
#  'Soft Coated Wheaten Terrier Mix': 23,
#  'Spanish Mastiff Mix': 1,
#  'Spanish Water Dog': 1,
#  'Sphynx': 2,
#  'Spinone Italiano Mix': 1,
#  'St. Bernard Rough Coat': 11,
#  'St. Bernard Rough Coat Mix': 5,
#  'St. Bernard Smooth Coat': 13,
#  'St. Bernard Smooth Coat Mix': 10,
#  'Staffordshire': 251,
#  'Staffordshire Mix': 94,
#  'Standard Poodle': 32,
#  'Standard Poodle Mix': 11,
#  'Standard Schnauzer': 20,
#  'Standard Schnauzer Mix': 12,
#  'Swedish Vallhund': 7,
#  'Swedish Vallhund Mix': 5,
#  'Swiss Hound': 1,
#  'Tan Hound': 31,
#  'Tan Hound Mix': 18,
#  'Tibetan Spaniel': 4,
#  'Tibetan Spaniel Mix': 3,
#  'Tibetan Terrier': 8,
#  'Tibetan Terrier Mix': 6,
#  'Tonkinese Mix': 4,
#  'Toy Fox Terrier': 11,
#  'Toy Fox Terrier Mix': 7,
#  'Toy Poodle': 53,
#  'Toy Poodle Mix': 36,
#  'Treeing Cur Mix': 4,
#  'Treeing Tennesse Brindle': 1,
#  'Treeing Walker Coonhound': 11,
#  'Treeing Walker Coonhound Mix': 8,
#  'Turkish Van Mix': 2,
#  'Unknown': 3,
#  'Unknown Mix': 2,
#  'Vizsla': 20,
#  'Vizsla Mix': 7,
#  'Weimaraner': 30,
#  'Weimaraner Mix': 19,
#  'Welsh Springer Spaniel': 2,
#  'Welsh Springer Spaniel Mix': 1,
#  'Welsh Terrier': 8,
#  'Welsh Terrier Mix': 5,
#  'West Highland': 26,
#  'West Highland Mix': 14,
#  'Whippet': 47,
#  'Whippet Mix': 21,
#  'Wire Hair Fox Terrier': 24,
#  'Wire Hair Fox Terrier Mix': 12,
#  'Wirehaired Pointing Griffon Mix': 2,
#  'Yorkshire': 267,
#  'Yorkshire Terrier': 266,
#  'Yorkshire Terrier Mix': 143}

# %% [markdown]
# Looking at these, we could try pulling out the 'mix' identifier.

# %%
new_breeds = list(np.unique([x.split(' Mix')[0] for x in breeds]))
new_breeds.append('Mix')
new_breed_cnts = dict([(x, sum([x in y for y in train_data['Breed']])) for x in new_breeds])

# %%
len(new_breed_cnts)
# Out:
# 226

# %%
new_breed_cnts
# Out:
# {'Abyssinian': 2,
#  'Affenpinscher': 10,
#  'Afghan Hound': 1,
#  'Airedale Terrier': 9,
#  'Akita': 29,
#  'Alaskan Husky': 26,
#  'Alaskan Malamute': 17,
#  'American Bulldog': 147,
#  'American Eskimo': 14,
#  'American Foxhound': 7,
#  'American Pit Bull Terrier': 90,
#  'American Shorthair': 9,
#  'American Staffordshire Terrier': 121,
#  'Anatol Shepherd': 152,
#  'Angora': 7,
#  'Australian Cattle Dog': 640,
#  'Australian Kelpie': 133,
#  'Australian Shepherd': 272,
#  'Australian Terrier': 4,
#  'Balinese': 5,
#  'Basenji': 24,
#  'Basset Hound': 101,
#  'Beagle': 311,
#  'Bearded Collie': 2,
#  'Beauceron': 14,
#  'Bedlington Terr': 3,
#  'Belgian Malinois': 20,
#  'Belgian Sheepdog': 3,
#  'Belgian Tervuren': 2,
#  'Bengal': 5,
#  'Bernese Mountain Dog': 9,
#  'Bichon Frise': 22,
#  'Black': 130,
#  'Black Mouth Cur': 101,
#  'Bloodhound': 12,
#  'Blue Lacy': 74,
#  'Bluetick Hound': 7,
#  'Boerboel': 4,
#  'Bombay': 5,
#  'Border Collie': 432,
#  'Border Terrier': 74,
#  'Borzoi': 1,
#  'Boston Terrier': 86,
#  'Boxer': 437,
#  'Boykin Span': 4,
#  'British Shorthair': 5,
#  'Brittany': 15,
#  'Bruss Griffon': 28,
#  'Bull Terrier': 140,
#  'Bull Terrier Miniature': 3,
#  'Bulldog': 230,
#  'Bullmastiff': 11,
#  'Burmese': 1,
#  'Cairn Terrier': 176,
#  'Canaan Dog': 6,
#  'Cane Corso': 8,
#  'Cardigan Welsh Corgi': 127,
#  'Carolina Dog': 49,
#  'Catahoula': 272,
#  'Cavalier Span': 19,
#  'Chesa Bay Retr': 14,
#  'Chihuahua Longhair': 193,
#  'Chihuahua Shorthair': 2398,
#  'Chinese Crested': 5,
#  'Chinese Sharpei': 94,
#  'Chow Chow': 150,
#  'Cocker Spaniel': 107,
#  'Collie Rough': 28,
#  'Collie Smooth': 50,
#  'Cornish Rex': 1,
#  'Cymric': 2,
#  'Dachshund': 787,
#  'Dachshund Longhair': 55,
#  'Dachshund Wirehair': 64,
#  'Dalmatian': 23,
#  'Devon Rex': 2,
#  'Doberman Pinsch': 79,
#  'Dogo Argentino': 17,
#  'Dogue De Bordeaux': 6,
#  'Domestic Longhair': 548,
#  'Domestic Medium Hair': 884,
#  'Domestic Shorthair': 8971,
#  'Dutch Shepherd': 9,
#  'English Bulldog': 53,
#  'English Cocker Spaniel': 4,
#  'English Coonhound': 8,
#  'English Foxhound': 4,
#  'English Pointer': 18,
#  'English Setter': 5,
#  'English Shepherd': 3,
#  'English Springer Spaniel': 9,
#  'Entlebucher': 1,
#  'Exotic Shorthair': 2,
#  'Feist': 6,
#  'Field Spaniel': 2,
#  'Finnish Spitz': 14,
#  'Flat Coat Retriever': 54,
#  'French Bulldog': 14,
#  'German Pinscher': 3,
#  'German Shepherd': 962,
#  'German Shorthair Pointer': 25,
#  'German Wirehaired Pointer': 5,
#  'Glen Of Imaal': 4,
#  'Golden Retriever': 126,
#  'Great Dane': 59,
#  'Great Pyrenees': 172,
#  'Greater Swiss Mountain Dog': 4,
#  'Greyhound': 50,
#  'Harrier': 27,
#  'Havana Brown': 1,
#  'Havanese': 17,
#  'Himalayan': 18,
#  'Hovawart': 1,
#  'Ibizan Hound': 4,
#  'Irish Setter': 3,
#  'Irish Terrier': 6,
#  'Irish Wolfhound': 6,
#  'Italian Greyhound': 26,
#  'Jack Russell Terrier': 270,
#  'Japanese Bobtail': 8,
#  'Japanese Chin': 3,
#  'Javanese': 2,
#  'Jindo': 3,
#  'Keeshond': 7,
#  'Kuvasz': 1,
#  'Labrador Retriever': 2274,
#  'Landseer': 6,
#  'Leonberger': 9,
#  'Lhasa Apso': 77,
#  'Lowchen': 1,
#  'Maine Coon': 47,
#  'Maltese': 131,
#  'Manchester Terrier': 68,
#  'Manx': 49,
#  'Mastiff': 58,
#  'Mexican Hairless': 1,
#  'Miniature Pinscher': 115,
#  'Miniature Poodle': 431,
#  'Miniature Schnauzer': 266,
#  'Mix': 22298,
#  'Munchkin Longhair': 1,
#  'Neapolitan Mastiff': 3,
#  'Newfoundland': 14,
#  'Norfolk Terrier': 34,
#  'Norwegian Elkhound': 1,
#  'Norwegian Forest Cat': 1,
#  'Norwich Terrier': 18,
#  'Nova Scotia Duck Tolling Retriever': 5,
#  'Ocicat': 1,
#  'Old English Bulldog': 3,
#  'Old English Sheepdog': 2,
#  'Otterhound': 1,
#  'Papillon': 29,
#  'Parson Russell Terrier': 30,
#  'Patterdale Terr': 6,
#  'Pbgv': 15,
#  'Pekingese': 43,
#  'Pembroke Welsh Corgi': 42,
#  'Persian': 16,
#  'Pharaoh Hound': 13,
#  'Picardy Sheepdog': 3,
#  'Pit Bull': 2392,
#  'Pixiebob Shorthair': 3,
#  'Plott Hound': 124,
#  'Podengo Pequeno': 5,
#  'Pointer': 239,
#  'Pomeranian': 73,
#  'Port Water Dog': 2,
#  'Presa Canario': 3,
#  'Pug': 143,
#  'Queensland Heeler': 73,
#  'Ragdoll': 13,
#  'Rat Terrier': 257,
#  'Redbone Hound': 34,
#  'Rex': 4,
#  'Rhod Ridgeback': 53,
#  'Rottweiler': 209,
#  'Russian Blue': 36,
#  'Saluki': 5,
#  'Samoyed': 3,
#  'Schipperke': 12,
#  'Schnauzer Giant': 5,
#  'Scottish Terrier': 7,
#  'Sealyham Terr': 1,
#  'Shetland Sheepdog': 42,
#  'Shiba Inu': 22,
#  'Shih Tzu': 190,
#  'Siamese': 430,
#  'Siberian Husky': 221,
#  'Silky Terrier': 8,
#  'Skye Terrier': 5,
#  'Smooth Fox Terrier': 11,
#  'Snowshoe': 78,
#  'Soft Coated Wheaten Terrier': 31,
#  'Spanish Mastiff': 1,
#  'Spanish Water Dog': 1,
#  'Sphynx': 2,
#  'Spinone Italiano': 1,
#  'St. Bernard Rough Coat': 11,
#  'St. Bernard Smooth Coat': 13,
#  'Staffordshire': 251,
#  'Standard Poodle': 32,
#  'Standard Schnauzer': 20,
#  'Swedish Vallhund': 7,
#  'Swiss Hound': 1,
#  'Tan Hound': 31,
#  'Tibetan Spaniel': 4,
#  'Tibetan Terrier': 8,
#  'Tonkinese': 4,
#  'Toy Fox Terrier': 11,
#  'Toy Poodle': 53,
#  'Treeing Cur': 4,
#  'Treeing Tennesse Brindle': 1,
#  'Treeing Walker Coonhound': 11,
#  'Turkish Van': 2,
#  'Unknown': 3,
#  'Vizsla': 20,
#  'Weimaraner': 30,
#  'Welsh Springer Spaniel': 2,
#  'Welsh Terrier': 8,
#  'West Highland': 26,
#  'Whippet': 47,
#  'Wire Hair Fox Terrier': 24,
#  'Wirehaired Pointing Griffon': 2,
#  'Yorkshire': 267,
#  'Yorkshire Terrier': 266}

# %%
'Manchester Terrier'.split(' Mix')
# Out:
# ['Manchester Terrier']

# %% [markdown]
# ## Color
#
# There are a lot of these.  They also need to be compressed.

# %%
x = 'Color'
cnts = train_data[x].groupby(train_data[x]).count().append(pd.Series({'nan': len(train_data[x]) - train_data[x].count()}))
cnts.sort_values()
# Out:
# nan                               0
# Chocolate/Gold                    1
# Chocolate/Gray                    1
# Chocolate/Red Tick                1
# Cream/Orange                      1
# Cream/Red                         1
# Cream/Red Tick                    1
# Cream/Seal Point                  1
# Fawn/Brown                        1
# Chocolate/Cream                   1
# Fawn/Brown Brindle                1
# Fawn/Tricolor                     1
# Gold/Black                        1
# Gold/Buff                         1
# Gold/Tan                          1
# Gold/Yellow                       1
# Gray Tabby/Black                  1
# Gray/Red                          1
# Liver Tick/White                  1
# Yellow/Yellow                     1
# Chocolate/Brown Merle             1
# Chocolate/Brown Brindle           1
# Calico/Orange Tabby               1
# Brown Brindle/Blue Tick           1
# Brown Brindle/Brown Brindle       1
# Brown Brindle/Brown Merle         1
# Brown Merle/Blue Merle            1
# Brown Merle/Tan                   1
# Brown Tabby/Brown                 1
# Brown Tabby/Gray Tabby            1
#                                ...
# Chocolate/White                 224
# Brown Brindle                   232
# Blue Tabby/White                241
# Red/White                       331
# Brown/Black                     333
# Torbie                          335
# Red                             337
# White/Tan                       389
# Blue Tabby                      433
# Black/Brown                     436
# Brown Brindle/White             450
# Blue                            450
# Orange Tabby/White              455
# Calico                          517
# Tortie                          530
# White/Brown                     569
# Tan                             628
# Brown                           639
# White/Black                     643
# Black/Tan                       672
# Blue/White                      702
# Tricolor                        752
# Tan/White                       773
# Orange Tabby                    841
# Brown/White                     884
# White                           931
# Brown Tabby/White               940
# Brown Tabby                    1635
# Black                          2292
# Black/White                    2824
# Length: 367, dtype: int64

# %% [markdown]
# First we'll get a list of all the colors, by separating the combos

# %%
from itertools import chain
colors = np.unique(list(chain.from_iterable([x.split('/') for x in train_data['Color']])))

# %%
color_cnts = dict([(x, sum([x in y for y in train_data['Color']])) for x in colors])

# %%
len(color_cnts)
# Out:
# 57

# %%
color_cnts
# Out:
# {'Agouti': 2,
#  'Apricot': 30,
#  'Black': 8024,
#  'Black Brindle': 114,
#  'Black Smoke': 69,
#  'Black Tabby': 67,
#  'Black Tiger': 2,
#  'Blue': 2354,
#  'Blue Cream': 34,
#  'Blue Merle': 181,
#  'Blue Point': 31,
#  'Blue Smoke': 6,
#  'Blue Tabby': 696,
#  'Blue Tick': 54,
#  'Blue Tiger': 9,
#  'Brown': 6693,
#  'Brown Brindle': 867,
#  'Brown Merle': 84,
#  'Brown Tabby': 2696,
#  'Brown Tiger': 5,
#  'Buff': 328,
#  'Calico': 583,
#  'Calico Point': 27,
#  'Chocolate': 519,
#  'Chocolate Point': 24,
#  'Cream': 612,
#  'Cream Tabby': 282,
#  'Fawn': 209,
#  'Flame Point': 86,
#  'Gold': 84,
#  'Gray': 407,
#  'Gray Tabby': 55,
#  'Lilac Point': 39,
#  'Liver': 31,
#  'Liver Tick': 4,
#  'Lynx Point': 188,
#  'Orange': 1438,
#  'Orange Tabby': 1353,
#  'Orange Tiger': 1,
#  'Pink': 4,
#  'Red': 985,
#  'Red Merle': 59,
#  'Red Tick': 59,
#  'Ruddy': 1,
#  'Sable': 324,
#  'Seal Point': 159,
#  'Silver': 122,
#  'Silver Lynx Point': 2,
#  'Silver Tabby': 42,
#  'Tan': 3025,
#  'Torbie': 398,
#  'Tortie': 618,
#  'Tortie Point': 34,
#  'Tricolor': 912,
#  'White': 12186,
#  'Yellow': 275,
#  'Yellow Brindle': 39}

# %% [markdown]
# ## Feature Exploration
